# %%
import pandas as pd

# %%
file = "superfundsites.csv"
data = pd.read_csv(file)

# %%
data
# Out:
#                Reg   St  \
# 0             ‭01‬   CT
# 1             ‭01‬   CT
# 2             ‭01‬   CT
# 3             ‭01‬   CT
# 4             ‭01‬   CT
# 5             ‭01‬   CT
# 6             ‭01‬   CT
# 7             ‭01‬   CT
# 8             ‭01‬   CT
# 9             ‭01‬   CT
# 10            ‭01‬   CT
# 11            ‭01‬   CT
# 12            ‭01‬   CT
# 13            ‭01‬   CT
# 14            ‭01‬   MA
# 15            ‭01‬   MA
# 16            ‭01‬   MA
# 17            ‭01‬   MA
# 18            ‭01‬   MA
# 19            ‭01‬   MA
# 20            ‭01‬   MA
# 21            ‭01‬   MA
# 22            ‭01‬   MA
# 23            ‭01‬   MA
# 24            ‭01‬   MA
# 25            ‭01‬   MA
# 26            ‭01‬   MA
# 27            ‭01‬   MA
# 28            ‭01‬   MA
# 29            ‭01‬   MA
# ...            ...  ...
# 1308          ‭10‬   WA
# 1309          ‭10‬   WA
# 1310          ‭10‬   WA
# 1311          ‭10‬   WA
# 1312          ‭10‬   WA
# 1313          ‭10‬   WA
# ...
